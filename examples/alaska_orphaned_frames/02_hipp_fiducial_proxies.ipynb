# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import hipp
import glob
import os
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c0c871c2-9049-4b61-b39b-3714177ccbbc" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## Inputs

# %%
data_directory = '.\\data'
images_directory = os.path.join(data_directory, 'raw_data', 'EEFrames', 'AK590', 'raw_images')

# %% [markdown]
# ## Get First Image

# %%
single_image_file = glob.glob(os.path.join(images_directory,'*.tif'))[0]

# %%
print(single_image_file)
# Out:
# .\data\raw_data\EEFrames\AK590\raw_images\AR4AK5900010009.tif

# %% [markdown]
# ## Create fiducial templates from images
#
# Note that the optional parameter buffer_distance should be tuned to the dataset you are using.

# %%
hipp.core.create_midside_fiducial_proxies_template(
    image_file = single_image_file,
    output_directory = os.path.join(data_directory, 'input', 'fiducials', 'ee', 'transparent_block'),
    buffer_distance = 250 # default value is 250

)
# Out:
# Select inner most point to crop from for midside fiducial marker proxies,
# in order from Left - Top - Right - Bottom.
# Launching server at http://localhost:57137
# '.\\data\\input\\fiducials\\ee\\transparent_block'

# %% [markdown]
# ## Detect principal points and crop images

# %%
hipp.batch.preprocess_with_fiducial_proxies(images_directory,
    template_directory = os.path.join(data_directory, 'input', 'fiducials', 'nagap', 'block'))
# Out:
# Detecting fiducial proxies...
# 100%|████████████████████████████████████████████████████████████████████████████████| 275/275 [03:47<00:00,  1.21it/s]
# WARNING: Unable to estimate principal point for: data/raw_data/EEFrames/A001330020082.tif
# WARNING: Using mean principal point estimate from image set instead.
# WARNING: Unable to estimate principal point for: data/raw_data/EEFrames/A001330020083.tif
# WARNING: Using mean principal point estimate from image set instead.
# WARNING: Unable to estimate principal point for: data/raw_data/EEFrames/A001330020084.tif
# WARNING: Using mean principal point estimate from image set instead.
# WARNING: Unable to estimate principal point for: data/raw_data/EEFrames/A001330020085.tif
# WARNING: Using mean principal point estimate from image set instead.
# WARNING: Unable to estimate principal point for: data/raw_data/EEFrames/A001330020086.tif
# WARNING: Using mean principal point estimate from image set instead.
# ...
